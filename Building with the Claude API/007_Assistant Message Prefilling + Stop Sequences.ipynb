# %%
# Install Dependencies
# %pip install anthropic python-dotenv
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: anthropic in /Users/islam/Library/Python/3.9/lib/python/site-packages (0.121.0)
# Requirement already satisfied: python-dotenv in /Users/islam/Library/Python/3.9/lib/python/site-packages (1.2.1)
# Requirement already satisfied: httpx<1,>=0.25.0 in /Users/islam/Library/Python/3.9/lib/python/site-packages (from anthropic) (0.28.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/islam/Library/Python/3.9/lib/python/site-packages (from anthropic) (4.12.1)
# Requirement already satisfied: sniffio<2,>=1 in /Users/islam/Library/Python/3.9/lib/python/site-packages (from anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in /Users/islam/Library/Python/3.9/lib/python/site-packages (from anthropic) (4.16.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/islam/Library/Python/3.9/lib/python/site-packages (from anthropic) (2.13.4)
# Requirement already satisfied: docstring-parser<1,>=0.15 in /Users/islam/Library/Python/3.9/lib/python/site-packages (from anthropic) (0.18.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/islam/Library/Python/3.9/lib/python/site-packages (from anthropic) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/islam/Library/Python/3.9/lib/python/site-packages (from anthropic) (0.16.0)
# Requirement already satisfied: idna>=2.8 in /Users/islam/Library/Python/3.9/lib/python/site-packages (from anyio<5,>=3.5.0->anthropic) (3.18)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/islam/Library/Python/3.9/lib/python/site-packages (from anyio<5,>=3.5.0->anthropic) (1.3.1)
# Requirement already satisfied: httpcore==1.* in /Users/islam/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: certifi in /Users/islam/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.25.0->anthropic) (2026.7.22)
# Requirement already satisfied: h11>=0.16 in /Users/islam/Library/Python/3.9/lib/python/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/islam/Library/Python/3.9/lib/python/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/islam/Library/Python/3.9/lib/python/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /Users/islam/Library/Python/3.9/lib/python/site-packages (from pydantic<3,>=1.9.0->anthropic) (2.46.4)
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
# Load env variables
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# Create an API client
from anthropic import Anthropic

client = Anthropic()
model = "claude-haiku-4-5" # sonnet-5 doesnt support the message prefill so using haiku here

# %%
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages, stop_sequences=None):

    params = {
            "model": model,
            "max_tokens": 1000,
            "messages": messages,
        }
    
    if stop_sequences is not None:
        params["stop_sequences"] = stop_sequences
    
    response = client.messages.create(**params)
    return "".join(block.text for block in response.content if block.type == "text")

# %%
# Make a starting list of messages
messages = []
add_user_message(messages, "Generate a very short event bridge rule as json")
add_assistant_message(messages, "```json")
text = chat(messages, stop_sequences=["```"])
print(text)
# Out:
# {
#   "Name": "MyRule",
#   "Description": "A simple EventBridge rule",
#   "EventBusName": "default",
#   "EventPattern": {
#     "source": ["aws.ec2"],
#     "detail-type": ["EC2 Instance State-change Notification"],
#     "detail": {
#       "state": ["running"]
#     }
#   },
#   "State": "ENABLED",
#   "Targets": [
#     {
#       "Arn": "arn:aws:lambda:us-east-1:123456789012:function:MyFunction",
#       "Id": "1"
#     }
#   ]
# }
