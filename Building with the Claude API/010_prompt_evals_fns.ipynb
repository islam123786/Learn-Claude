# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex",
        "solution_criteria": "Key criteria for evaluating the solution"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 6 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Criteria you should use to evaluate the solution:
<criteria>
{test_case["solution_criteria"]}
</criteria>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}

* Respond only with Python, JSON, or a plain Regex
* Do not add any comments or commentary or explanation
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```code")
    output = chat(messages, stop_sequences=["```"])
    return output

# %%
# Functions to validate the output structure
import re
import ast


def validate_json(text):
    try:
        json.loads(text.strip())
        return 10
    except json.JSONDecodeError:
        return 0


def validate_python(text):
    try:
        ast.parse(text.strip())
        return 10
    except SyntaxError:
        return 0


def validate_regex(text):
    try:
        re.compile(text.strip())
        return 10
    except re.error:
        return 0


def grade_syntax(response, test_case):
    format = test_case["format"]
    if format == "json":
        return validate_json(response)
    elif format == "python":
        return validate_python(response)
    else:
        return validate_regex(response)

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    model_score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    syntax_score = grade_syntax(output, test_case)

    score = (model_score + syntax_score) / 2

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 8.5

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "\n{\n  \"FunctionName\": \"S3EventProcessor\",\n  \"Runtime\": \"python3.11\",\n  \"Role\": \"arn:aws:iam::ACCOUNT_ID:role/lambda-s3-role\",\n  \"Handler\": \"index.lambda_handler\",\n  \"Timeout\": 60,\n  \"MemorySize\": 256,\n  \"Environment\": {\n    \"Variables\": {\n      \"BUCKET_NAME\": \"my-s3-bucket\",\n      \"AWS_REGION\": \"us-east-1\"\n    }\n  },\n  \"Events\": [\n    {\n      \"Type\": \"s3:ObjectCreated:*\",\n      \"Properties\": {\n        \"Bucket\": \"my-s3-bucket\",\n        \"Events\": [\n          \"s3:ObjectCreated:*\",\n          \"s3:ObjectRemoved:*\"\n        ]\n      }\n    }\n  ],\n  \"Layers\": [],\n  \"EphemeralStorage\": {\n    \"Size\": 512\n  },\n  \"PackageType\": \"Zip\",\n  \"Architectures\": [\n    \"x86_64\"\n  ]\n}\n",
#     "test_case": {
#       "task": "Create a JSON configuration file for an AWS Lambda function that processes S3 bucket events, with environment variables for the bucket name and region",
#       "format": "json",
#       "solution_criteria": "Valid JSON with Lambda function configuration, S3 event source mapping, and environment variables section"
#     },
#     "score": 7.5,
#     "reasoning": "The configuration demonstrates good understanding of Lambda parameters and correctly implements the environment variables requirement. However, the Events section is structurally incompatible with actual AWS Lambda API specifications. S3 event sources cannot be configured directly within the Lambda function definition\u2014they require separate S3 bucket notification configuration or infrastructure-as-code tools. The solution would not deploy successfully as written."
#   },
#   {
#     "output": "\nimport re\nfrom typing import Tuple, Optional\n\ndef extract_arn_components(arn: str) -> Optional[Tuple[str, str]]:\n    \"\"\"\n    Extracts AWS account ID and resource type from an ARN string.\n    \n    ARN format: arn:partition:service:region:account-id:resource-type/resource-id\n    or: arn:partition:service:region:account-id:resource-type:resource-id\n    \"\"\"\n    pattern = r'arn:aws:[^:]+:[^:]*:([^:]+):([^:/]+)'\n    match = re.match(pattern, arn)\n    \n    if match:\n        account_id = match.group(1)\n        resource_type = match.group(2)\n        return (account_id, resource_type)\n    \n    return None\n\n\ndef extract_arn_components_alternative(arn: str) -> Optional[Tuple[str, str]]:\n    \"\"\"Alternative implementation using simple string splitting.\"\"\"\n    try:\n        parts = arn.split(':')\n        if len(parts) >= 6:\n            account_id = parts[4]\n            resource_part = parts[5]\n            resource_type = resource_part.split('/')[0].split(':')[0]\n            return (account_id, resource_type)\n    except (IndexError, AttributeError):\n        pass\n    \n    return None\n\n\nif __name__ == \"__main__\":\n    test_arns = [\n        \"arn:aws:iam::123456789012:user/Development/product_1234/*\",\n        \"arn:aws:s3:::my_corporate_bucket/*\",\n        \"arn:aws:ec2:us-east-1:123456789012:instance/i-1234567890abcdef0\",\n        \"arn:aws:lambda:us-east-1:123456789012:function:my-function\",\n        \"arn:aws:rds:us-east-1:123456789012:db:mydbinstance\"\n    ]\n    \n    for arn in test_arns:\n        result = extract_arn_components(arn)\n        print(f\"ARN: {arn}\")\n        print(f\"Result: {result}\\n\")\n",
#     "test_case": {
#       "task": "Write a Python function that extracts the AWS account ID and resource type from an ARN string",
#       "format": "python",
#       "solution_criteria": "Function correctly parses ARN format (arn:aws:service:region:account-id:resource) and returns both components"
#     },
#     "score": 7.5,
#     "reasoning": "The solution demonstrates good coding practices with documentation and multiple approaches, but has a critical flaw: AWS ARNs vary significantly across services. Many services (S3, IAM without paths, etc.) don't include account IDs in their ARN structure. The current regex pattern `([^:]+):([^:/]+)` assumes both components always exist at positions 5 and 6, which is incorrect for approximately 30-40% of common AWS ARNs. The solution should either gracefully handle missing account IDs (returning optional fields) or document this limitation explicitly. The alternative implementation has the same flaw. For the given test cases, results would be: IAM user (works), S3 (fails - returns None), EC2 instance (works), Lambda (works), RDS (works) - a 60% success rate."
#   },
#   {
#     "output": "\n^[a-z0-9]([a-z0-9-]{1,61}[a-z0-9])?$\n",
#     "test_case": {
#       "task": "Create a regular expression pattern that matches valid AWS S3 bucket names (3-63 characters, lowercase letters, numbers, and hyphens only, cannot start or end with hyphen)",
#       "format": "regex",
#       "solution_criteria": "Regex correctly validates S3 bucket naming rules and rejects invalid names"
#     },
#     "score": 9.0,
#     "reasoning": "The regex pattern correctly validates AWS S3 bucket naming rules by ensuring: (1) first character is lowercase letter or number, (2) middle characters can be lowercase, numbers, or hyphens (1-61 characters), (3) last character is lowercase or number (optional for 3-char minimum case). While the logic is sound and enforces all rules correctly, the use of an optional group with `?` creates ambiguity about whether 2-character names are intentionally supported. In practice, this pattern works correctly for the AWS requirement of 3-63 characters because the first `[a-z0-9]` is mandatory and the optional second group requires at least 2 more characters when present, resulting in 3+ characters minimum."
#   },
#   {
#     "output": "\nimport json\nfrom datetime import datetime\n\ndef iso8601_to_unix(iso_timestamp: str) -> int:\n    \"\"\"Convert ISO 8601 timestamp from AWS CloudWatch logs to Unix timestamp.\"\"\"\n    # AWS CloudWatch uses ISO 8601 format: \"2023-10-15T12:34:56.789Z\"\n    dt = datetime.fromisoformat(iso_timestamp.replace('Z', '+00:00'))\n    return int(dt.timestamp())\n\n# Test examples\nif __name__ == \"__main__\":\n    test_cases = [\n        \"2023-10-15T12:34:56.789Z\",\n        \"2024-01-01T00:00:00.000Z\",\n        \"2023-06-30T23:59:59.999Z\"\n    ]\n    \n    for timestamp in test_cases:\n        unix_time = iso8601_to_unix(timestamp)\n        print(json.dumps({\n            \"iso8601\": timestamp,\n            \"unix_timestamp\": unix_time\n        }))\n",
#     "test_case": {
#       "task": "Write a Python function that converts an ISO 8601 timestamp from AWS CloudWatch logs into a Unix timestamp (seconds since epoch)",
#       "format": "python",
#       "solution_criteria": "Function correctly parses ISO 8601 format and converts to Unix timestamp integer"
#     },
#     "score": 8.5,
#     "reasoning": "The solution correctly implements the core requirement: parsing ISO 8601 timestamps and converting them to Unix timestamps. The approach of replacing 'Z' with '+00:00' is the standard workaround for Python's fromisoformat() limitations. However, the code lacks production-ready robustness with no input validation or error handling. For AWS CloudWatch integration, functions should validate inputs since malformed logs could crash the parser."
#   },
#   {
#     "output": "\n{\n  \"Version\": \"2012-10-17\",\n  \"Statement\": [\n    {\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"ec2:DescribeInstances\",\n        \"ec2:DescribeTags\",\n        \"ec2:DescribeInstanceStatus\"\n      ],\n      \"Resource\": \"*\"\n    },\n    {\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"ec2:TerminateInstances\"\n      ],\n      \"Resource\": \"arn:aws:ec2:*:*:instance/*\",\n      \"Condition\": {\n        \"StringEquals\": {\n          \"ec2:ResourceTag/Environment\": \"temporary\"\n        }\n      }\n    }\n  ]\n}\n",
#     "test_case": {
#       "task": "Create a JSON IAM policy document that allows EC2 describe operations on all instances and allows terminating instances with a specific tag",
#       "format": "json",
#       "solution_criteria": "Valid IAM policy JSON with correct Action, Resource, and Condition statements using tag-based conditions"
#     },
#     "score": 9.0,
#     "reasoning": "The policy correctly implements the stated requirements with valid JSON syntax and appropriate use of tag-based conditions for role-based access control. The describe operations are unrestricted to '*' as requested, while terminate operations are properly scoped using conditional tag matching. The policy follows IAM best practices for least privilege. However, there is a minor concern about the practical enforceability of EC2 tag conditions on the TerminateInstances action in real-world scenarios, though the syntax itself is correct."
#   },
#   {
#     "output": "\n^AKIA[A-Z0-9]{16}$\n",
#     "test_case": {
#       "task": "Write a regular expression to validate AWS access key IDs (format: AKIA followed by 16 alphanumeric uppercase characters)",
#       "format": "regex",
#       "solution_criteria": "Regex correctly matches the AKIA prefix and validates the exact length and character requirements"
#     },
#     "score": 9.5,
#     "reasoning": "The regex correctly implements all core requirements: AKIA prefix, exactly 16 alphanumeric uppercase characters, and boundary enforcement. The solution is precise, concise, and matches AWS access key ID specifications accurately. Minor considerations around preprocessing are implementation concerns rather than regex design flaws."
#   }
# ]
